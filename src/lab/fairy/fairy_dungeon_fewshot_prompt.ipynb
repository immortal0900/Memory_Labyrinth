# %%
from langchain_core.documents import Document  
from agents.fairy.util import FAIRY_DUNGEON_FEW_SHOTS

docs = []
for intent, block in FAIRY_DUNGEON_FEW_SHOTS.items():
    docs.append(
        Document(
            page_content=f"fewshots for intent={intent.name}",
            metadata={
                "intent": intent.name,
                "fewshot_block": block,
                "kind": "intent_block",
            },
        )
    )
