# %%
import os, sys
from pathlib import Path
from dotenv import load_dotenv
load_dotenv()
def find_src_folder():
    current = Path(os.getcwd()).resolve()
    for p in [current] + list(current.parents):
        src = p / "src"
        if src.exists():
            return src
    raise RuntimeError("src 폴더를 찾을 수 없습니다.")

src_path = find_src_folder()
sys.path.append(str(src_path))

# %%
from agents.fairy.fairy_dungeon_agent import graph_builder as dungeon_builder
from agents.fairy.fairy_state import FairyState
from langgraph.graph import START, END, StateGraph
from agents.fairy.util import add_human_message

graph_builder = StateGraph(FairyState)

def dungeon_node(state:FairyState):
    question = state["question"]
    add_human_message(content = question)
    dungeon_builder.compile()
    builder = graph_builder.invoke()    
    
graph_builder.add_edge()
graph_builder.add_node()
